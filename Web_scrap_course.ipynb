# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://boston.craigslist.org/search/sof"

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
data = response.text

# %%
data
# Out:
# '\ufeff<!DOCTYPE html>\n<html class="no-js"><head>\n    <title>boston software/qa/dba/etc  - craigslist</title>\n    <script type="application/ld+json">\n    {"@context":"https://schema.org","itemListElement":[{"item":{"name":"boston.craigslist.org","@id":"https://boston.craigslist.org"},"position":1,"@type":"ListItem"},{"item":{"name":"jobs","@id":"https://boston.craigslist.org/search/jjj"},"position":2,"@type":"ListItem"},{"item":{"name":"software","@id":"https://boston.craigslist.org/search/sof"},"position":3,"@type":"ListItem"}],"@type":"BreadcrumbList"}\n</script>\n\n    <meta name="description" content="boston software/qa/dba/etc  - craigslist">\n    <meta http-equiv="X-UA-Compatible" content="IE=Edge"/>\n    <link rel="canonical" href="https://boston.craigslist.org/search/sof">\n    <link rel="alternate" type="application/rss+xml" href="https://boston.craigslist.org/search/sof?format=rss" title="RSS feed for craigslist | boston software/qa/dba/etc  - craigslist">\n    <meta name="viewport" content="width=device-width,initial-scale=1">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/cl.css?v=d6ed290bc3b4b54de607517150cee045">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/search.css?v=fe8a7c504444218d6dae2e065e40d511">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/jquery-ui-clcustom.css?v=3b05ddffb7c7f5b62066deff2dda9339">\n<link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/leaflet.css?v=d604b055c4c11b9fd29d0c071b394312">\n<link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/MarkerCluster.css?v=9bea97021e746649c6837e95dd9723e8">\n<link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps.css?v=d8743547c59d5ad31d4d7294c7e2f7f2">\n<!--[if IE]>\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps-ie.css?v=6bcbe5817e70c9a7f673ff72ba3e56e5">\n<![endif]-->\n\n    \n        <script type="text/javascript"><!--\nvar areaCountry = "US";\nvar areaID = "4";\nvar areaRegion = "MA";\nvar catAbb = "sof";\nvar countOfTotalText = "image {count} of {total}";\nvar currencySymbol = "&#x0024;";\nvar defaultView = "list";\nvar expiredFavIDs = null;\nvar imageConfig = {"4":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"3":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}};\nvar lessInfoText = "less info";\nvar maptileBaseUrl = "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png";\nvar maxResults = 3000;\nvar noImageText = "no image";\nvar pID = null;\nvar postalLat = null;\nvar postalLon = null;\nvar purveyorCategories = null;\nvar searchDistance = null;\nvar sectionAbb = "jjj";\nvar sectionBase = "jjj";\nvar showInfoText = "show info";\nvar showMapTabs = 1;\nvar showingBanished = 0;\nvar showingFavorites = 0;\nvar starHint = "save this post in your favorites list";\nvar subarea = null;\nvar zoomToPosting = null;\n--></script>\n    \n</head>\n<body class="search has-map">\n    <script type="text/javascript"><!--\n    function C(k){return(document.cookie.match(\'(^|; )\'+k+\'=([^;]*)\')||0)[2]}\n    var pagetype, pagemode;\n    (function(){\n        var h = document.documentElement;\n        h.className = h.className.replace(\'no-js\', \'js\');\n        var b = document.body;\n        var bodyClassList = b.className.split(/\\s+/);;\n        pagetype = bodyClassList[0]; // dangerous assumption\n        var fmt = C(\'cl_fmt\');\n        if ( fmt === \'regular\' || fmt === \'mobile\' ) {\n            pagemode = ...

# %%
soup = BeautifulSoup(data,'html.parser')

# %%
tags = soup.find_all('a')

# %%
n = soup.find_all('div')
s = soup.find_all('span')

# %%
len(s)
# Out:
# 258

# %%
len(n)
# Out:
# 62

# %%
len(tags)
# Out:
# 86

# %%
for tag in tags:
    print(tag.get('href'))
# Out:
# https://play.google.com/store/apps/details?id=org.craigslist.CraigslistMobile
# https://apps.apple.com/us/app/craigslist/id1336642410
# /
# /
# https://post.craigslist.org/c/bos
# https://accounts.craigslist.org/login/home
# #
# #
# /
# https://accounts.craigslist.org/savesearch/save?URL=https%3A%2F%2Fboston%2Ecraigslist%2Eorg%2Fsearch%2Fsof
# /search/sof
# /search/sof
# /search/sof?sort=date&
# /search/sof
# /search/sof
#
# https://boston.craigslist.org/nos/sof/d/east-boston-two-separate-interns/7203032610.html
# https://boston.craigslist.org/nos/sof/d/east-boston-two-separate-interns/7203032610.html
# #
# https://boston.craigslist.org/sob/sof/d/scituate-part-time-licensed-oil-burner/7202193569.html
# https://boston.craigslist.org/sob/sof/d/scituate-part-time-licensed-oil-burner/7202193569.html
# #
# https://boston.craigslist.org/gbs/sof/d/cambridge-archive-developer/7201619486.html
# https://boston.craigslist.org/gbs/sof/d/cambridge-archive-developer/7201619486.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7201519463.html
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7201519463.html
# #
# https://boston.craigslist.org/gbs/sof/d/cambridge-software-engineer-automated/7200936561.html
# https://boston.craigslist.org/gbs/sof/d/cambridge-software-engineer-automated/7200936561.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-software-engineer-per-year/7200363325.html
# https://boston.craigslist.org/gbs/sof/d/boston-software-engineer-per-year/7200363325.html
# #
# https://boston.craigslist.org/gbs/sof/d/dorchester-senior-software-engineer/7200186147.html
# https://boston.craigslist.org/gbs/sof/d/dorchester-senior-software-engineer/7200186147.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-software-engineer-brio-per-year/7198543337.html
# https://boston.craigslist.org/gbs/sof/d/boston-software-engineer-brio-per-year/7198543337.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7197368233.html
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7197368233.html
# #
# https://boston.craigslist.org/gbs/sof/d/cambridge-software-engineer-automated/7196226953.html
# https://boston.craigslist.org/gbs/sof/d/cambridge-software-engineer-automated/7196226953.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7193774846.html
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7193774846.html
# #
# https://boston.craigslist.org/gbs/sof/d/cambridge-software-engineer-automated/7193700891.html
# https://boston.craigslist.org/gbs/sof/d/cambridge-software-engineer-automated/7193700891.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7188465452.html
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7188465452.html
# #
# https://boston.craigslist.org/gbs/sof/d/cambridge-software-engineer-automated/7188338784.html
# https://boston.craigslist.org/gbs/sof/d/cambridge-software-engineer-automated/7188338784.html
# #
# https://providence.craigslist.org/sof/d/providence-software-engineer-full-stack/7201655412.html
# https://providence.craigslist.org/sof/d/providence-software-engineer-full-stack/7201655412.html
# #
# https://providence.craigslist.org/sof/d/cranston-software-developer-programmer/7200368391.html
# https://providence.craigslist.org/sof/d/cranston-software-developer-programmer/7200368391.html
# #
# https://providence.craigslist.org/sof/d/php-xml-web-developer-work/7197965448.html
# https://providence.craigslist.org/sof/d/php-xml-web-developer-work/7197965448.html
# #
# https://capecod.craigslist.org/sof/d/woods-hole-database-specialist/7201466507.html
# https://capecod.craigslist.org/sof/d/woods-hole-database-specialist/7201466507.html
# #
# https://hartford.craigslist.org/sof/d/bloomfield-need-help-working-with/7193804118.html
# https://hartford.craigslist.org/sof/d/bloomfield-need-help-working-with/7193804118.html
# #
# #page-top
# #page-top
# /search/sof
# /search/sof
#
# https://boston.craigslist.org/search/sof?format=rss
# https://www.craigslist.org/about/rss
# https://www.craigslist.org/about/help/
# https://www.craigslist.org/about/scams
# https://www.craigslist.org/about/privacy.policy
# https://forums.craigslist.org/?forumID=8
# https://www.craigslist.org/about/terms.of.use
# https://www.craigslist.org/about/

# %%
titles = soup.find_all("a",{"class": "result-title"})

# %%
for title in titles:
    print(title.text)
# Out:
# Two Separate Interns-Android and iPhone
# Part-time licensed Oil Burner/AC Technician
# Archive Developer
# Data Science Fellowship
# Software Engineer, Automated Mapping | Toyota
# Software Engineer | $80,000 - $120,000 per year
# Senior Software Engineer (Full Stack)
# Software Engineer | Brio | $80,000 - $120,000 per year
# Data Science Fellowship
# Software Engineer, Automated Mapping | Toyota
# Data Science Fellowship
# Software Engineer, Automated Mapping | Toyota
# Data Science Fellowship
# Software Engineer, Automated Mapping | Toyota
# Software Engineer - Full-Stack, ABCya
# Software Developer Programmer
# PHP XML Web Developer Work
# Database Specialist
# Need help working with “Shopify” software

# %%
adresses = soup.find_all("span",{"class":"result-hood"})

# %%
for adress in adresses:
    print(adress.text)
# Out:
#  (boston)
#  (South Shore)
#  (Cambridge, MA)
#  (Cambridge)
#  (Remote)
#  (Cambridge)
#  (Cambridge)
#  (Cambridge)

# %%
jobs = soup.find_all('div',{'class':'result-info'})

# %%
# jobs = soup.find_all('p')

# %%
jobs
# Out:
# [<div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2020-09-25 18:50" title="Fri 25 Sep 06:50:18 PM">Sep 25</time>
#  <h2>
#  <a class="result-title hdrlnk" data-id="7203032610" href="https://boston.craigslist.org/nos/sof/d/east-boston-two-separate-interns/7203032610.html" id="postid_7203032610">Two Separate Interns-Android and iPhone</a>
#  </h2>
#  <span class="result-meta">
#  <span class="result-hood"> (boston)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>, <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2020-09-24 13:30" title="Thu 24 Sep 01:30:24 PM">Sep 24</time>
#  <h2>
#  <a class="result-title hdrlnk" data-id="7202193569" href="https://boston.craigslist.org/sob/sof/d/scituate-part-time-licensed-oil-burner/7202193569.html" id="postid_7202193569">Part-time licensed Oil Burner/AC Technician</a>
#  </h2>
#  <span class="result-meta">
#  <span class="result-hood"> (South Shore)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>, <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2020-09-23 14:27" title="Wed 23 Sep 02:27:22 PM">Sep 23</time>
#  <h2>
#  <a class="result-title hdrlnk" data-id="7201619486" href="https://boston.craigslist.org/gbs/sof/d/cambridge-archive-developer/7201619486.html" id="postid_7201619486">Archive Developer</a>
#  </h2>
#  <span class="result-meta">
#  <span class="result-hood"> (Cambridge, MA)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>, <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2020-09-23 12:19" title="Wed 23 Sep 12:19:54 PM">Sep 23</time>
#  <h2>
#  <a class="result-title hdrlnk" data-id="7201519463" href="https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7201519463.html" id="postid_7201519463">Data Science Fellowship</a>
#  </h2>
#  <span class="result-meta">
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>, <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2020-09-22 13:13" title="Tue 22 Sep 01:13:58 PM">Sep 22</time>
#  <h2>
#  <a class="result-title hdrlnk" data-id="7200936561" href="https://boston.craigslist.org/gbs/sof/d/cambridge-software-engineer-automated/7200936561.html" id="postid_7200936561">Software Engineer, Automated Mapping | Toyota</a>
#  </h2>
#  <span class="result-meta">
#  <span class="result-hood"> (Cambridge)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>, <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2020-09-21 14:36" title="Mon 21 Sep 02:36:39 PM">Sep 21</time>
#  <h2>
#  <a class="result-title hdrlnk" data-id="7200363325" href="https://boston.craigslist.org/gbs/sof/d/boston-software-engineer-per-year/7200363325.html" id="postid_7200363325">Software Engineer | $80,000 - $120,000 per year</a>
#  </h2>
#  <span class="result-meta">
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>, <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2020-09-21 10:59" title="Mon 21 Sep 10:59:32 AM">Sep 21</time>
#  <h2>
#  <a class="result-title hdrlnk" data-id="7200186147" href="https://boston.craigslist.org/gbs/sof/d/dorchester-senior-software-engineer/7200186147.html" id="postid_7200186147">Senior Software Engineer (Full Stack)</a>
#  </h2>
#  <span class="result-meta">
#  <span class="result-hood"> (Remote)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>, <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2020-09-18 13:07" title="Fri 18 Sep 01:07:07 PM">Sep 18</time>
#  <h2>
#  <a class="result-title hdrlnk" data-id="7198543337" href="https://boston.craigslist.org/gbs/sof/d/boston-software-engineer-brio-per-year/7198543337.html" id="postid_7198543337">Software Engineer | Brio | $80,000 - $120,000 per year</a>
#  </h2>
#  <span class="result-meta">
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>, <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2020-09-16 13:52" title="Wed 16 Sep 01:52:36 PM">Sep 16</time>
#  <h2>
#  <a class="result-title hdrlnk" data-id="7197368233" href="https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7197368233.html" id="postid_7197368233">Data Science Fellowship</a>
#  </h2>
#  <span class="result-meta">
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>, <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2020-09-14 16:10" title="Mon 14 Sep 04:10:42 PM">Sep 14</time>
#  <h2>
#  <a class="result-title hdrlnk" data-id="7196226953" href="https://boston.craigslist.org/gbs/sof/d/cambridge-software-engineer-automated/7196226953.html" id="postid_7196226953">Software Engineer, Automated Mapping | Toyota</a>
#  </h2>
#  <span class="result-meta">
#  <span class="result-hood"> (Cambridge)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>, <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2020-09-10 14:42" title="Thu 10 Sep 02:42:39 PM">Sep 10</time>
#  <h2>
#  <a class="result-title hdrlnk" data-id="7193774846" href="https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7193774846.html" id="postid_7193774846">Data Science Fellowship</a>
#  </h2>
#  <span class="result-meta">
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>, <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2020-09-10 13:06" title="Thu 10 Sep 01:06:07 PM">Sep 10</time>
#  <h2>
#  <a class="result-title hdrlnk" data-id="7193700891" href="https://boston.craigslist.org/gbs/sof/d/cambridge-software-engineer-automated/7193700891.html" id="postid_7193700891">Software Engineer, Automated Mapping | Toyota</a>
#  </h2>
#  <span class="result-meta">
#  <span class="result-hood"> (Cambridge)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>, <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2020-09-01 16:16" title="Tue 01 Sep 04:16:15 PM">Sep  1</time>
#  <h2>
#  <a class="result-title hdrlnk" data-id="7188465452" href="https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7188465452.html" id="postid_7188465452">Data Science Fellowship</a>
#  </h2>
#  <span class="result-meta">
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>, <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2020-09-01 13:26" title="Tue 01 Sep 01:26:21 PM">Sep  1</time>
#  <h2>
#  <a class="result-title hdrlnk" data-id="7188338784" href="https://boston.craigslist.org/gbs/sof/d/cambridge-software-engineer-automated/7188338784.html" id="postid_7188338784">Software Engineer, Automated Mapping | Toyota</a>
#  </h2>
#  <span class="result-meta">
#  <span class="result-hood"> (Cambridge)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>, <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2020-09-23 15:15" title="Wed 23 Sep 03:15:17 PM">Sep 23</time>
#  <h2>
#  <a class="result-title hdrlnk" data-id="7201655412" href="https://providence.craigslist.org/sof/d/providence-software-engineer-full-stack/7201655412.html" id="postid_7201655412">Software Engineer - Full-Stack, ABCya</a>
#  </h2>
#  <span class="result-meta">
#  <span class="nearby" title="rhode island">(prv &gt; Providence, RI)</span>
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>, <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2020-09-21 14:43" title="Mon 21 Sep 02:43:08 PM">Sep 21</time>
#  <h2>
#  <a class="result-title hdrlnk" data-id="7200368391" href="https://providence.craigslist.org/sof/d/cranston-software-developer-programmer/7200368391.html" id="postid_7200368391">Software Developer Programmer</a>
#  </h2>
#  <span class="result-meta">
#  <span class="nearby" title="rhode island">(prv &gt; Cranston, RI)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>, <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2020-09-17 13:52" title="Thu 17 Sep 01:52:35 PM">Sep 17</time>
#  <h2>
#  <a class="result-title hdrlnk" data-id="7197965448" href="https://providence.craigslist.org/sof/d/php-xml-web-developer-work/7197965448.html" id="postid_7197965448">PHP XML Web Developer Work</a>
#  </h2>
#  <span class="result-meta">
#  <span class="nearby" title="rhode island">(prv &gt; East Greenwich)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>, <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2020-09-23 11:09" title="Wed 23 Sep 11:09:54 AM">Sep 23</time>
#  <h2>
#  <a class="result-title hdrlnk" data-id="7201466507" href="https://capecod.craigslist.org/sof/d/woods-hole-database-specialist/7201466507.html" id="postid_7201466507">Database Specialist</a>
#  </h2>
#  <span class="result-meta">
#  <span class="nearby" title="cape cod / islands">(cap &gt; Falmouth, MA)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>, <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2020-09-10 15:21" title="Thu 10 Sep 03:21:37 PM">Sep 10</time>
#  <h2>
#  <a class="result-title hdrlnk" data-id="7193804118" href="https://hartford.craigslist.org/sof/d/bloomfield-need-help-working-with/7193804118.html" id="postid_7193804118">Need help working with “Shopify” software</a>
#  </h2>
#  <span class="result-meta">
#  <span class="nearby" title="hartford, CT">(htf &gt; Bloomfield)</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>]

# %%
len(jobs)
# Out:
# 19

# %%
for job in jobs:
    print(job.text)
# Out:
# favorite this post
#
# Sep 25
#
# Two Separate Interns-Android and iPhone
#
#
#  (boston)
#
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
# favorite this post
#
# Sep 24
#
# Part-time licensed Oil Burner/AC Technician
#
#
#  (South Shore)
#
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
# favorite this post
#
# Sep 23
#
# Archive Developer
#
#
#  (Cambridge, MA)
#
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
# favorite this post
#
# Sep 23
#
# Data Science Fellowship
#
#
#
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
# favorite this post
#
# Sep 22
#
# Software Engineer, Automated Mapping | Toyota
#
#
#  (Cambridge)
#
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
# favorite this post
#
# Sep 21
#
# Software Engineer | $80,000 - $120,000 per year
#
#
#
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
# favorite this post
#
# Sep 21
#
# Senior Software Engineer (Full Stack)
#
#
#  (Remote)
#
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
# favorite this post
#
# Sep 18
#
# Software Engineer | Brio | $80,000 - $120,000 per year
#
#
#
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
# favorite this post
#
# Sep 16
#
# Data Science Fellowship
#
#
#
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
# favorite this post
#
# Sep 14
#
# Software Engineer, Automated Mapping | Toyota
#
#
#  (Cambridge)
#
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
# favorite this post
#
# Sep 10
#
# Data Science Fellowship
#
#
#
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
# favorite this post
#
# Sep 10
#
# Software Engineer, Automated Mapping | Toyota
#
#
#  (Cambridge)
#
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
# favorite this post
#
# Sep  1
#
# Data Science Fellowship
#
#
#
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
# favorite this post
#
# Sep  1
#
# Software Engineer, Automated Mapping | Toyota
#
#
#  (Cambridge)
#
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
# favorite this post
#
# Sep 23
#
# Software Engineer - Full-Stack, ABCya
#
#
# (prv > Providence, RI)
#
# pic
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
# favorite this post
#
# Sep 21
#
# Software Developer Programmer
#
#
# (prv > Cranston, RI)
#
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
# favorite this post
#
# Sep 17
#
# PHP XML Web Developer Work
#
#
# (prv > East Greenwich)
#
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
# favorite this post
#
# Sep 23
#
# Database Specialist
#
#
# (cap > Falmouth, MA)
#
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
# favorite this post
#
# Sep 10
#
# Need help working with “Shopify” software
#
#
# (htf > Bloomfield)
#
#
#
# hide this posting
#
#
#
# restore
# restore this posting

# %%
for job in jobs:
    title = job.find('a',{'class': 'result-title hdrlnk'}).text
    location_tag = job.find('span',{'class': 'result-hood'})
    location = location_tag.text[2:-1] if location_tag else "N/A"
    date = job.find('time',{'class':'result-date'}).text
    link = job.find('a',{'class': 'result-title'}).get('href')
    job_response = requests.get(link)
    job_data = job_response.text
    job_soup = BeautifulSoup(job_data, 'html.parser')
    job_description = job_soup.find('section',{'id': 'postingbody'}).text
    job_attributes_tag =job_soup.find('p',{'class':'attrgroup'})
    job_attributes = job_attributes_tag.text if job_attributes_tag else "N/A"
    
    #print('job Title:', title, '\nLocation', location, '\nData:',data, '\nLink:', link, '\n---')
    print('job Title:', title, '\nLocation:', location, '\nDate: ', date, '\nLink: ', link, "/n", job_attributes, '\nJob Description: ', job_description)
# Out:
# job Title: Two Separate Interns-Android and iPhone
# Location: boston
# Date:  Sep 25
# Link:  https://boston.craigslist.org/nos/sof/d/east-boston-two-separate-interns/7203032610.html /n
# compensation: $10/hr max $600, with completion target of Dec 15th
#
# employment type: part-time
#
# internship
#
# telecommuting ok
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# I am seeking two separate Smartphone college "intern" developers. One to focus on Android and the other on iOS. The task is to integrate two existing separate Smartphone versions of the same app. The apps are both connected to a php/server using a standard RESTful API protocol. The existing apps are well written but basically undocumented.
# The goal it to modify them so that they will connect to a standard, but private, LINUX server environment.
# At least in the initial effort, there will not be a lot of original programming involved. Therefore, due diligence and the ability to research and understand the fairly large code base of the specific Smartphone type, are key.
# I have completed quite a bit of preliminary analysis. I will provide that information to help with defining the areas of focus.
# The intern must fully understand how to publish and test the Apps using the respective Play stores.
# The Android app is written using Android Studio in Java while the iOS code is written in Swift.
# You will be reporting to, me, a senior computer scientist who will manage the backend while you manage the respective Smartphone app.
# The pay is at the “intern” level of $10 per hour with a budget of $600 per Smartphone. The project is targeted for completion prior to Christmas school break. However, there is the possibility of you being on the ground floor of a unique and major economic success.
# The source code is under a private Git repo. A Non-Disclosure Agreement is required.
# In summary:
# 1.	You must already be fluent in the specific Smartphone’s Code
# 2.	You must already know how to publish an Android or iPhone app
# 3.	You must be capable of accepting stringent reviews and carrying out directions.
#
# job Title: Part-time licensed Oil Burner/AC Technician
# Location: South Shore
# Date:  Sep 24
# Link:  https://boston.craigslist.org/sob/sof/d/scituate-part-time-licensed-oil-burner/7202193569.html /n
# compensation: Compensation based on experience
#
# employment type: part-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Growing 24 hour full-service South Shore Heating Oil Business  looking for a
# Part-time licensed Oil Burner/AC Technician.
# Requirements include:
# Maintenance, repair and trouble shooting experience with all heating and AC systems.
# Experience with installation and replacement of all systems.
# Product ordering with suppliers
# Availability for on call service hours
# Excellent customer service skills
# Ability to manage multi-faceted tasks
# Experience in a fast paced environment
#
# job Title: Archive Developer
# Location: Cambridge, MA
# Date:  Sep 23
# Link:  https://boston.craigslist.org/gbs/sof/d/cambridge-archive-developer/7201619486.html /n
# compensation: Competitive
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Archive Developer (2 positions)
# Chandra X-ray Telescope Data System
#
# Ad Keywords: Software, developer, programmer, software engineer, archive, database, astronomy, NASA, Chandra, CfA)
#
# This is an opportunity with the Data Systems division of the Chandra X-ray Center, which is part of the High Energy Astrophysics Division of the Smithsonian Astrophysical Observatory in Cambridge MA. One of NASA’s Earth-orbiting Great Observatories, the Chandra X-ray telescope has been observing for over 20 years and continues to have a positive impact on the scientific understanding of the universe. We seek two Software Developers for the archive group to contribute to the continued success of the mission.
#
# Join the Chandra X-ray Center and become part of the team working to extend and maintain the Chandra Data archive functionality and to support its operations. The archive contains terabytes of data from the Chandra mission, ensures their integrity, security, and uninterrupted access, and provides interfaces for archiving and retrieval to Science Center Operations and Chandra Science users.
#
# Duties include:
# *  Communicating with scientists and operations teams for software requirements
# * Developing and maintaining software through all phases of the software development lifecycle
# * Documenting software for CXC operations staff and scientific users worldwide
# * Release deployment, server and data migrations, and data archive monitoring
# * Problem analysis and evaluation in support of archive operations and scientific user input
# * Work as part of a team
#
# Knowledge required for the position includes:
# * Proficiency in C++ and Java
# * Experience in SQL/rDBMS
# * Familiarity with relational database servers, web, and JEE application servers in a Unix environment
# * Experience in scripting languages (e.g., Python, Perl) are beneficial since parts of the system include code written in these languages
#
# We offer a challenging and fulfilling working environment in partnership with scientists, operations staff, and an existing software development group, to bring Chandra data to the astronomical community at large.
#
# Benefits include health and dental insurance, vacation and sick time, an institution contributed retirement plan, a flexible spending account, and several insurance opportunities that are all described at the USAJobs link below or on request from the contact person identified on the site.
#
# We accept only on-line applications for this position. For complete information and online application procedures, please visit
#
# https://www.usajobs.gov/GetJob/ViewDetails/578814100
#
# We are an equal employment opportunity employer, committed to diversity in our workplace.
# job Title: Data Science Fellowship
# Location: N/A
# Date:  Sep 23
# Link:  https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7201519463.html /n
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting ok
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
#
# Pathrise (YC W18) invests in undervalued university students or young professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from heads of marketing of publicly traded companies to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 500 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
#
# The Pathrise Fellowship is a program for students and new grads that helps you land the best job possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry data scientists, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
#
# We seek to uplift and provide guidance for undervalued students and young professionals in their early career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
#
# You want to work with an experienced advisor who can give you expert advice.
# You are eager to start your career with a job or internship at a top tech company or a rapidly growing startup.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=craigslist&utm_campaign=bosdata&utm_medium=job_board
# job Title: Software Engineer, Automated Mapping | Toyota
# Location: Cambridge
# Date:  Sep 22
# Link:  https://boston.craigslist.org/gbs/sof/d/cambridge-software-engineer-automated/7200936561.html /n
# compensation: Competitive
#
# employment type: full-time
#
# telecommuting ok
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/726481c8/apply
#
#
# HireArt is helping TRI hire a skilled and highly motivated Software Engineer to support the development and performance of high-definition maps for autonomous driving. This position is fully remote and has potential for extension for the right candidate. Applicants based throughout the U.S. who can accommodate a Pacific Timezone work schedule are welcome to apply. In an era of increasing vehicle automation, having up-to-date and highly accurate maps is critical to ensuring safe vehicle operation both on the highway and on surface roads. As Software Engineer, Mapping, you’ll have the opportunity to work with engineers and researchers innovating in autonomous mapping and driving technology. The ideal candidate is an adept engineer experienced in Linux, Git, and C++. You're also a great communicator, collaborator, and problem-solver. As Software Engineer, Mapping you will:
# Collaborate with other software engineers and research scientists to improve the software behind maintaining high-definition maps for autonomous driving.
# Be at the front-line interfaces between engineers, researchers, and map annotators to decrease turn-around time for map updates and feature requests.
# With the guidance of senior software engineers, implement high-quality software to allow for both high-performance and easily understandable and maintainable software.
# Live and breathe the software practices that produce maintainable code, including automated testing, continuous integration, code style conformity, and code review.
#
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/726481c8/apply
#
#
# Requirements
#
# B.S. in Computer Science or a related field
# 2+ years of professional experience in related position
# A great team player and collaborator
# Strong communication skills
# Experienced in Linux, Git, and C++.
# Experience with 3D graphics/OpenGL preferred
# Ability to work with Python code as needed
# Commitment: This is a full-time (40 hours per week), 6-month contract position with potential for extension. This role is staffed via HireArt and based in Los Altos, CA. This position is fully remote and applicants based throughout the U.S. who can accommodate a Pacific Timezone work schedule are welcome to apply. HireArt provides Equal Employment Opportunity without regard to the applicant's race, color, creed, gender, gender identity or expression, sexual orientation, national origin, age, physical or mental disability, medical condition, religion, marital status, genetic information, veteran status, or any other status protected under federal, state or local laws. We are interested in every qualified candidate who is eligible to work in the United States. Unfortunately, we are not able to sponsor visas.
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/726481c8/apply
#
#
# About Toyota Research Institute
# At Toyota Research Institute (TRI), we’re working to build a future where everyone has the freedom to move, engage, and explore with a focus on reducing vehicle collisions, injuries, and fatalities. Join us in our mission to improve the quality of human life through advances in artificial intelligence, automated driving, robotics and materials science. We’re dedicated to building a world of “mobility for all” where everyone, regardless of age or ability, can live in harmony with technology to enjoy a better life. Through innovations in AI, we’ll...● Develop vehicles incapable of causing a crash, regardless of the actions of the driver.● Develop technology for vehicles and robots to help people enjoy new levels of independence, access, and mobility.● Bring advanced mobility technology to market faster.● Discover new materials that will make drive batteries and hydrogen fuel cells smaller, lighter, less expensive and more powerful.Our work is guided by a dedication to safety – in how we research, develop, and validate the performance of vehicle technology to benefit society. As a subsidiary of Toyota, TRI is fueled by a diverse and inclusive community of people who carry invaluable leadership, experience, and ideas from industry-leading companies. Over half of our technical team carries PhD degrees. We’re continually searching for the world’s best talent ‒ people who are ready to define the new world of mobility with us!We strive to build a company that helps our people thrive, achieve work life balance, and bring their best selves to work. At TRI, you will have the opportunity to enjoy the best of both worlds ‒ a fun start up environment with brilliant people who enjoy solving tough problems and the financial backing to successfully achieve our goals. If you’re passionate about working with smart people to make cars safer, enable the elderly to age in place, or design alternative fuel sources, TRI is the place for you. ‒ Start your impossible with us. https://www.tri.global/
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/726481c8/apply
# job Title: Software Engineer | $80,000 - $120,000 per year
# Location: N/A
# Date:  Sep 21
# Link:  https://boston.craigslist.org/gbs/sof/d/boston-software-engineer-per-year/7200363325.html /n
# compensation: $80,000 - $120,000 per year
#
# employment type: full-time
#
# telecommuting ok
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/6704f6fc/apply
#
#
# HireArt is helping Brio Systems hire a skilled and motivated Software Engineer. As a growing startup dedicated to biotechnology and wellness, Brio’s current efforts are focused on enabling access to COVID-19 testing.This position can be performed remotely from anywhere in the U.S. The ability to accommodate typical Eastern Standard Time working hours is required. Brio aims to empower employers to test their teams proactively and on their terms, and gain the insights they need to understand and slow on-site outbreaks, keep employees safe, and manage risk as part of their return-to-work strategies.This is a rare opportunity to get involved in solving a truly meaningful problem with massive scale. The product is up and running, and there is still a ton of room to make your mark as an early member of the team.We’re seeking a Software Engineer who gets excited about challenges, fast-changing environments, and problems with no clear solution. You like to run a disciplined process, but you don’t let it stifle you. You are intuitive but love and respect data. You are opinionated, but equally open to the opinions of others. As Software Engineer, you will:
# Be comfortable across the stack from DevOps to back-end and front-end code, with a passion and strength in at least one zone.
# Follow right-sized processes for development, QC, and release, and be an advocate for evolving them as the company grows.
# Keep the data of users and partners safe through secure code, secure infrastructure, and secure processes.
# Work with the team to define and achieve delivery schedules.
# Contribute to technical specs and plans.
# Work across the board with product designers, sales, and others to deliver the best possible experience to our customers.
# Make a big impact in the company, and on the world.
# The current stack:
# Python 3, Flask, PostgreSQL, and Redis, running on AWS.
# Server-rendered HTML via Jinja, with Javascript and PostCSS, moving towards React.
#
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/6704f6fc/apply
#
#
# Requirements
#
# 3+ years of experience with web-technology coding on a deployed commercial software product
# Demonstrated history of increasing responsibility on the teams and projects you’ve contributed to
# Ability to work in a high-stakes environment where results are critical
# Live experience with back-end development, architecture, and deployment and/or front-end design methodologies and frameworks
# Understanding of creating secure API interfaces, ACL’s, etc.
# Significant, demonstrable experience with current tech stack frameworks and technologies - AWS, Python, PostgreSQL, JavaScript
# Additional qualifications:
# Experience with Microservices
# Experience working on remote teams
# Experience in high-criticality and high-stakes industries like health, finance, aerospace
# Experience working in a seed-stage, high growth startup environment
# Passion for or working knowledge of health, wellness or biology-related topics
# Commitment: This is a full-time (40+ hours per week), contract-to-hire position staffed via HireArt and based in Boston, MA. This position can be performed remotely from anywhere in the U.S. The ability to accommodate typical Eastern Standard Time working hours is required. HireArt values diversity and is an Equal Opportunity Employer. We are interested in every qualified candidate who is eligible to work in the United States. Unfortunately, we are not able to sponsor visas.
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/6704f6fc/apply
#
#
# About Brio
# BRIO was created to empower individuals with a science-based platform to better understand their health. Founded in 2017, we have developed relationships with labs, medical providers, and employers - all parties who can work together to broaden access to COVID-19 testing. Our expertise puts us in a unique position to help expand testing access through employers, and we have focused all of our company efforts to work on this problem. Crunchbase recently listed us as a ‘Startup to Watch’ and we’re always proud to be picked up by our local tech journalists. We’re currently fully remote, with a center of gravity around Boston, MA where we were founded.
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/6704f6fc/apply
#
#
# job Title: Senior Software Engineer (Full Stack)
# Location: Remote
# Date:  Sep 21
# Link:  https://boston.craigslist.org/gbs/sof/d/dorchester-senior-software-engineer/7200186147.html /n
# compensation: $120-$150k base plus benefits, equity
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Senior Software Engineer (Full Stack)
#
# Clinical Research IO (CRIO) aims to transform and streamline the process of clinical trials, replacing the traditional paper-based manual workflows with a SAAS solution that improves efficiency and reduces error. Our business operates at the intersection of healthcare and life-science research. Our customers include clinical research sites, hospitals, biotech and pharma. We have developed an enterprise solution for research investigators, and we are embarking on building a platform for biotech and pharma sponsors. We provide value to our customers in this highly regulated industry by capturing data that is clean and accurate, eliminating expensive human intervention, and making research data available in real-time.
#
# We’re looking to expand our team of developers located in our Boston office!
# As part of our agile team, you’ll be working in a startup environment where you’ll have the opportunity to work closely with our customers and product team as we deliver enhancements and build new products in an industry with a mission to improve the quality of human life.
#
# About Us
# We are a small, fast-growing startup company with a strong team of developers, a loyal customer base, and a highly regarded brand. Our company culture emphasizes trust, teamwork, collaboration, learning, career growth, and fun! In our streamlined startup environment, nobody is just a developer. Each of us wears many hats, gets to know our customers and business, and has opportunities to contribute broadly to the company mission. Our people are our most important asset, and we build our team carefully to maintain the values of our culture.
#
# About You
# You are an experienced and dedicated engineer who cares deeply about your craft. You aren’t bound by specific tools and technology, and you feel confident picking up whatever skills you’ll need to get the job done. You are a good communicator, and you support your position with facts while maintaining an ability to compromise when necessary. You are committed to best practices, and you take personal ownership of the quality of your product. You enjoy collaboration, and thrive in a team environment where everyone is working towards a common goal. You enjoy getting to know your team on a personal level, and you love finding ways to have fun while doing your job!
#
# Responsibilities
# - Be a key contributor on a full stack SCRUM team
# - Develop new SAAS products and functionality hosted in the cloud
# - Collaborate with product leadership and UX to understand the needs of the business
# - Provide design influence to our product development
# - Mentor junior members of the team on best practices, design, and development
# - Participate in agile backlog grooming and planning sessions
# - Contribute to code review and design sessions
# - Stay current with industry trends, and bring the best of these into our engineering practices
#
# Technical Skills
# - 5+ years developing cloud-hosted SAAS applications on the front-end and back-end
# - Strong knowledge of Javascript, CSS, jQuery and HTML5
# - Experience with React, Vue.js or AngularJS
# - Strong knowledge of Java web technologies including Spring Boot and older frameworks
# - Solid experience with relational databases
# - Experience with unit testing and test-driven development
# - Experience working in a CI/CD environment
# - Understanding of scalability and performance concerns and strategies
# - Ability to design extensible and maintainable software
# - Comprehensive understanding of computer science concepts
#
# Leadership Skills
# - Excellent written and verbal communication skills
# - Ability to influence team as needed
# - Self-motivated and proactive in terms of identifying and resolving problems
# - Passionate about technology and staying current with industry trends
# - Natural tendency towards continuous improvement for self and team
#
# Nice to Have
# - Experience with Docker and Kubernetes
# - Experience with Google Cloud Platform
# - Experience with legacy Java Struts
# - Experience with healthcare or life science industries
# - Experience with 21CFR11, HIPAA, and GDPR regulatory conformance
#
#
#
#
# The Berkner Group has been retained to execute this search. If you were contacted by The Berkner Group, please reply to the person who contacted you. If you are applying to a job posting, please email your resume and a brief introduction to careers@berknergroup.com. Please include your name and the title for this position (“[Your name] — CRIO -  Senior Software Engineer”) in the subject line of your email.
# We look forward to hearing from you!
# job Title: Software Engineer | Brio | $80,000 - $120,000 per year
# Location: N/A
# Date:  Sep 18
# Link:  https://boston.craigslist.org/gbs/sof/d/boston-software-engineer-brio-per-year/7198543337.html /n
# compensation: $80,000 - $120,000 per year
#
# employment type: full-time
#
# telecommuting ok
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/6704f6fc/apply
#
#
# HireArt is helpful Brio Systems hire a skilled and motivated Software Engineer. As a growing startup dedicated to biotechnology and wellness, Brio’s current efforts are focused on enabling access to COVID-19 testing.This position can be performed remotely from anywhere in the U.S. The ability to accommodate typical Eastern Standard Time working hours is required. Brio aims to empower employers to test their teams proactively and on their terms, and gain the insights they need to understand and slow on-site outbreaks, keep employees safe, and manage risk as part of their return-to-work strategies.This is a rare opportunity to get involved in solving a truly meaningful problem with massive scale. The product is up and running, and there is still a ton of room to make your mark as an early member of the team.We’re seeking a Software Engineer who gets excited about challenges, fast-changing environments, and problems with no clear solution. You like to run a disciplined process, but you don’t let it stifle you. You are intuitive but love and respect data. You are opinionated, but equally open to the opinions of others. As Software Engineer, you will:
# Be comfortable across the stack from DevOps to back-end and front-end code, with a passion and strength in at least one zone.
# Follow right-sized processes for development, QC, and release, and be an advocate for evolving them as the company grows.
# Keep the data of users and partners safe through secure code, secure infrastructure, and secure processes.
# Work with the team to define and achieve delivery schedules.
# Contribute to technical specs and plans.
# Work across the board with product designers, sales, and others to deliver the best possible experience to our customers.
# Make a big impact in the company, and on the world.
# The current stack:
# Python 3, Flask, PostgreSQL, and Redis, running on AWS.
# Server-rendered HTML via Jinja, with Javascript and PostCSS, moving towards React.
#
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/6704f6fc/apply
#
#
# Requirements
#
# 3+ years of experience with web-technology coding on a deployed commercial software product
# Demonstrated history of increasing responsibility on the teams and projects you’ve contributed to
# Live experience with back-end development, architecture, and deployment and/or front-end design methodologies and frameworks
# Understanding of creating secure API interfaces, ACL’s, etc.
# Significant, demonstrable experience with current tech stack frameworks and technologies - AWS, Python, PostgreSQL, JavaScript
# Additional qualifications:
# Experience with Microservices
# Experience working on remote teams
# Experience in high-criticality and high-stakes industries like health, finance, aerospace
# Experience working in a seed-stage, high growth startup environment
# Passion for or working knowledge of health, wellness or biology-related topics
# Commitment: This is a full-time (40+ hours per week), contract-to-hire position staffed via HireArt and based in Boston, MA. This position can be performed remotely from anywhere in the U.S. The ability to accommodate typical Eastern Standard Time working hours is required. HireArt values diversity and is an Equal Opportunity Employer. We are interested in every qualified candidate who is eligible to work in the United States. Unfortunately, we are not able to sponsor visas.
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/6704f6fc/apply
#
#
# About Brio
# BRIO was created to empower individuals with a science-based platform to better understand their health. Founded in 2017, we have developed relationships with labs, medical providers, and employers - all parties who can work together to broaden access to COVID-19 testing. Our expertise puts us in a unique position to help expand testing access through employers, and we have focused all of our company efforts to work on this problem. Crunchbase recently listed us as a ‘Startup to Watch’ and we’re always proud to be picked up by our local tech journalists. We’re currently fully remote, with a center of gravity around Boston, MA where we were founded.
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/6704f6fc/apply
#
#
# job Title: Data Science Fellowship
# Location: N/A
# Date:  Sep 16
# Link:  https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7197368233.html /n
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting ok
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
#
# Pathrise (YC W18) invests in undervalued university students or young professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from heads of marketing of publicly traded companies to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 500 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
#
# The Pathrise Fellowship is a program for students and new grads that helps you land the best job possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry data scientists, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
#
# We seek to uplift and provide guidance for undervalued students and young professionals in their early career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
#
# You want to work with an experienced advisor who can give you expert advice.
# You are eager to start your career with a job or internship at a top tech company or a rapidly growing startup.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=craigslist&utm_campaign=bosdata&utm_medium=job_board
# job Title: Software Engineer, Automated Mapping | Toyota
# Location: Cambridge
# Date:  Sep 14
# Link:  https://boston.craigslist.org/gbs/sof/d/cambridge-software-engineer-automated/7196226953.html /n
# compensation: Competitive
#
# employment type: full-time
#
# telecommuting ok
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/726481c8/apply
#
#
# HireArt is helping TRI hire a skilled and highly motivated Software Engineer to support the development and performance of high-definition maps for autonomous driving. This position is fully remote and has potential for extension for the right candidate. Applicants based throughout the U.S. who can accommodate a Pacific Timezone work schedule are welcome to apply. In an era of increasing vehicle automation, having up-to-date and highly accurate maps is critical to ensuring safe vehicle operation both on the highway and on surface roads. As Software Engineer, Mapping, you’ll have the opportunity to work with engineers and researchers innovating in autonomous mapping and driving technology. The ideal candidate is an adept engineer experienced in Linux, Git, and C++. You're also a great communicator, collaborator, and problem-solver. As Software Engineer, Mapping you will:
# Collaborate with other software engineers and research scientists to improve the software behind maintaining high-definition maps for autonomous driving.
# Be at the front-line interfaces between engineers, researchers, and map annotators to decrease turn-around time for map updates and feature requests.
# With the guidance of senior software engineers, implement high-quality software to allow for both high-performance and easily understandable and maintainable software.
# Live and breathe the software practices that produce maintainable code, including automated testing, continuous integration, code style conformity, and code review.
#
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/726481c8/apply
#
#
# Requirements
#
# B.S. in Computer Science or a related field
# 2+ years of professional experience in related position
# A great team player and collaborator
# Strong communication skills
# Experienced in Linux, Git, and C++.
# Experience with 3D graphics/OpenGL preferred
# Ability to work with Python code as needed
# Commitment: This is a full-time (40 hours per week), 6-month contract position with potential for extension. This role is staffed via HireArt and based in Los Altos, CA. This position is fully remote and applicants based throughout the U.S. who can accommodate a Pacific Timezone work schedule are welcome to apply. HireArt provides Equal Employment Opportunity without regard to the applicant's race, color, creed, gender, gender identity or expression, sexual orientation, national origin, age, physical or mental disability, medical condition, religion, marital status, genetic information, veteran status, or any other status protected under federal, state or local laws. We are interested in every qualified candidate who is eligible to work in the United States. Unfortunately, we are not able to sponsor visas.
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/726481c8/apply
#
#
# About Toyota Research Institute
# At Toyota Research Institute (TRI), we’re working to build a future where everyone has the freedom to move, engage, and explore with a focus on reducing vehicle collisions, injuries, and fatalities. Join us in our mission to improve the quality of human life through advances in artificial intelligence, automated driving, robotics and materials science. We’re dedicated to building a world of “mobility for all” where everyone, regardless of age or ability, can live in harmony with technology to enjoy a better life. Through innovations in AI, we’ll...● Develop vehicles incapable of causing a crash, regardless of the actions of the driver.● Develop technology for vehicles and robots to help people enjoy new levels of independence, access, and mobility.● Bring advanced mobility technology to market faster.● Discover new materials that will make drive batteries and hydrogen fuel cells smaller, lighter, less expensive and more powerful.Our work is guided by a dedication to safety – in how we research, develop, and validate the performance of vehicle technology to benefit society. As a subsidiary of Toyota, TRI is fueled by a diverse and inclusive community of people who carry invaluable leadership, experience, and ideas from industry-leading companies. Over half of our technical team carries PhD degrees. We’re continually searching for the world’s best talent ‒ people who are ready to define the new world of mobility with us!We strive to build a company that helps our people thrive, achieve work life balance, and bring their best selves to work. At TRI, you will have the opportunity to enjoy the best of both worlds ‒ a fun start up environment with brilliant people who enjoy solving tough problems and the financial backing to successfully achieve our goals. If you’re passionate about working with smart people to make cars safer, enable the elderly to age in place, or design alternative fuel sources, TRI is the place for you. ‒ Start your impossible with us. https://www.tri.global/
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/726481c8/apply
# job Title: Data Science Fellowship
# Location: N/A
# Date:  Sep 10
# Link:  https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7193774846.html /n
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting ok
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
#
# Pathrise (YC W18) invests in undervalued university students or young professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from heads of marketing of publicly traded companies to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 500 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
#
# The Pathrise Fellowship is a program for students and new grads that helps you land the best job possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry data scientists, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
#
# We seek to uplift and provide guidance for undervalued students and young professionals in their early career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
#
# You want to work with an experienced advisor who can give you expert advice.
# You are eager to start your career with a job or internship at a top tech company or a rapidly growing startup.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=craigslist&utm_campaign=bosdata&utm_medium=job_board
# job Title: Software Engineer, Automated Mapping | Toyota
# Location: Cambridge
# Date:  Sep 10
# Link:  https://boston.craigslist.org/gbs/sof/d/cambridge-software-engineer-automated/7193700891.html /n
# compensation: Competitive
#
# employment type: full-time
#
# telecommuting ok
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/726481c8/apply
#
#
# HireArt is helping TRI hire a skilled and highly motivated Software Engineer to support the development and performance of high-definition maps for autonomous driving. This position is fully remote and has potential for extension for the right candidate. Applicants based throughout the U.S. who can accommodate a Pacific Timezone work schedule are welcome to apply. In an era of increasing vehicle automation, having up-to-date and highly accurate maps is critical to ensuring safe vehicle operation both on the highway and on surface roads. As Software Engineer, Mapping, you’ll have the opportunity to work with engineers and researchers innovating in autonomous mapping and driving technology. The ideal candidate is an adept engineer experienced in Linux, Git, and C++. You're also a great communicator, collaborator, and problem-solver. As Software Engineer, Mapping you will:
# Collaborate with other software engineers and research scientists to improve the software behind maintaining high-definition maps for autonomous driving.
# Be at the front-line interfaces between engineers, researchers, and map annotators to decrease turn-around time for map updates and feature requests.
# With the guidance of senior software engineers, implement high-quality software to allow for both high-performance and easily understandable and maintainable software.
# Live and breathe the software practices that produce maintainable code, including automated testing, continuous integration, code style conformity, and code review.
#
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/726481c8/apply
#
#
# Requirements
#
# B.S. in Computer Science or a related field
# 2+ years of professional experience in related position
# A great team player and collaborator
# Strong communication skills
# Experienced in Linux, Git, and C++.
# Experience with 3D graphics/OpenGL preferred
# Ability to work with Python code as needed
# Commitment: This is a full-time (40 hours per week), 6-month contract position with potential for extension. This role is staffed via HireArt and based in Los Altos, CA. This position is fully remote and applicants based throughout the U.S. who can accommodate a Pacific Timezone work schedule are welcome to apply. HireArt provides Equal Employment Opportunity without regard to the applicant's race, color, creed, gender, gender identity or expression, sexual orientation, national origin, age, physical or mental disability, medical condition, religion, marital status, genetic information, veteran status, or any other status protected under federal, state or local laws. We are interested in every qualified candidate who is eligible to work in the United States. Unfortunately, we are not able to sponsor visas.
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/726481c8/apply
#
#
# About Toyota Research Institute
# At Toyota Research Institute (TRI), we’re working to build a future where everyone has the freedom to move, engage, and explore with a focus on reducing vehicle collisions, injuries, and fatalities. Join us in our mission to improve the quality of human life through advances in artificial intelligence, automated driving, robotics and materials science. We’re dedicated to building a world of “mobility for all” where everyone, regardless of age or ability, can live in harmony with technology to enjoy a better life. Through innovations in AI, we’ll...● Develop vehicles incapable of causing a crash, regardless of the actions of the driver.● Develop technology for vehicles and robots to help people enjoy new levels of independence, access, and mobility.● Bring advanced mobility technology to market faster.● Discover new materials that will make drive batteries and hydrogen fuel cells smaller, lighter, less expensive and more powerful.Our work is guided by a dedication to safety – in how we research, develop, and validate the performance of vehicle technology to benefit society. As a subsidiary of Toyota, TRI is fueled by a diverse and inclusive community of people who carry invaluable leadership, experience, and ideas from industry-leading companies. Over half of our technical team carries PhD degrees. We’re continually searching for the world’s best talent ‒ people who are ready to define the new world of mobility with us!We strive to build a company that helps our people thrive, achieve work life balance, and bring their best selves to work. At TRI, you will have the opportunity to enjoy the best of both worlds ‒ a fun start up environment with brilliant people who enjoy solving tough problems and the financial backing to successfully achieve our goals. If you’re passionate about working with smart people to make cars safer, enable the elderly to age in place, or design alternative fuel sources, TRI is the place for you. ‒ Start your impossible with us. https://www.tri.global/
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/726481c8/apply
#
#
# job Title: Data Science Fellowship
# Location: N/A
# Date:  Sep  1
# Link:  https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7188465452.html /n
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting ok
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
#
# Pathrise (YC W18) invests in undervalued university students or young professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from heads of marketing of publicly traded companies to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 500 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
#
# The Pathrise Fellowship is a program for students and new grads that helps you land the best job possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry data scientists, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
#
# We seek to uplift and provide guidance for undervalued students and young professionals in their early career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
#
# You want to work with an experienced advisor who can give you expert advice.
# You are eager to start your career with a job or internship at a top tech company or a rapidly growing startup.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=craigslist&utm_campaign=bosdata&utm_medium=job_board
# job Title: Software Engineer, Automated Mapping | Toyota
# Location: Cambridge
# Date:  Sep  1
# Link:  https://boston.craigslist.org/gbs/sof/d/cambridge-software-engineer-automated/7188338784.html /n
# compensation: Competitive
#
# employment type: full-time
#
# telecommuting ok
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/726481c8/apply
#
#
# HireArt is helping TRI hire a skilled and highly motivated Software Engineer to support the development and performance of high-definition maps for autonomous driving. This position is fully remote and has potential for extension for the right candidate. Applicants based throughout the U.S. who can accommodate a Pacific Timezone work schedule are welcome to apply. In an era of increasing vehicle automation, having up-to-date and highly accurate maps is critical to ensuring safe vehicle operation both on the highway and on surface roads. As Software Engineer, Mapping, you’ll have the opportunity to work with engineers and researchers innovating in autonomous mapping and driving technology. The ideal candidate is an adept engineer experienced in Linux, Git, and C++. You're also a great communicator, collaborator, and problem-solver. As Software Engineer, Mapping you will:
# Collaborate with other software engineers and research scientists to improve the software behind maintaining high-definition maps for autonomous driving.
# Be at the front-line interfaces between engineers, researchers, and map annotators to decrease turn-around time for map updates and feature requests.
# With the guidance of senior software engineers, implement high-quality software to allow for both high-performance and easily understandable and maintainable software.
# Live and breathe the software practices that produce maintainable code, including automated testing, continuous integration, code style conformity, and code review.
#
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/726481c8/apply
#
#
# Requirements
#
# B.S. in Computer Science or a related field
# 2+ years of professional experience in related position
# A great team player and collaborator
# Strong communication skills
# Experienced in Linux, Git, and C++.
# Experience with 3D graphics/OpenGL preferred
# Ability to work with Python code as needed
# ...
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/726481c8/apply
#
#
# About Toyota Research Institute
# At Toyota Research Institute (TRI), we’re working to build a future where everyone has the freedom to move, engage, and explore with a focus on reducing vehicle collisions, injuries, and fatalities. Join us in our mission to improve the quality of human life through advances in artificial intelligence, automated driving, robotics and materials science. We’re dedicated to building a world of “mobility for all” where everyone, regardless of age or ability, can live in harmony with technology to enjoy a better life. Through innovations in AI, we’ll...● Develop vehicles incapable of causing a crash, regardless of the actions of the driver.● Develop technology for vehicles and robots to help people enjoy new levels of independence, access, and mobility.● Bring advanced mobility technology to market faster.● Discover new materials that will make drive batteries and hydrogen fuel cells smaller, lighter, less expensive and more powerful.Our work is guided by a dedication to safety – in how we research, develop, and validate the performance of vehicle technology to benefit society. As a subsidiary of Toyota, TRI is fueled by a diverse and inclusive community of people who carry invaluable leadership, experience, and ideas from industry-leading companies. Over half of our technical team carries PhD degrees. We’re continually searching for the world’s best talent ‒ people who are ready to define the new world of mobility with us!We strive to build a company that helps our people thrive, achieve work life balance, and bring their best selves to work. At TRI, you will have the opportunity to enjoy the best of both worlds ‒ a fun start up environment with brilliant people who enjoy solving tough problems and the financial backing to successfully achieve our goals. If you’re passionate about working with smart people to make cars safer, enable the elderly to age in place, or design alternative fuel sources, TRI is the place for you. ‒ Start your impossible with us. https://www.tri.global/
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/726481c8/apply
#
#
# job Title: Software Engineer - Full-Stack, ABCya
# Location: N/A
# Date:  Sep 23
# Link:  https://providence.craigslist.org/sof/d/providence-software-engineer-full-stack/7201655412.html /n
# compensation: Competitive salary and benefits
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# ABCya, a division of IXL Learning, is the leader in educational computer games and mobile apps for kids. The innovation of a grade school teacher, ABCya is an award-winning destination for Pre-K, elementary, and middle school students that offers hundreds of fun, engaging learning activities.
#
# Millions of kids, parents, and teachers visit ABCya.com each month, playing over 1 billion games last year. ABCya's educational games have been featured by Apple, The New York Times, USA Today, Parents Magazine, Scholastic, and other notable publications. ABCya is located in Providence, and our office is accessible by car or bus.
#
#
# WHAT YOU'LL BE DOING
# As a Full-Stack Software Engineer at ABCya, you will assist in maintaining back-end services and databases, build and maintain the GraphQL API, and help build our web clients. You’ll be leading the back-end development effort and assisting with front-end tasks as needed. In addition to working with your fellow engineers, you’ll collaborate with other teams to design amazing products that meet the needs of our users, who are kids, parents, and teachers all over the world.
#
# TECHNOLOGY
#
#
# Our backend stack includes Amazon Web Services, Prisma/ Nexus Prisma, Serverless Framework, MySQL, Netlify, GitLab and Stripe.
#
# The API code is written in GraphQL, JavaScript/Node.js and TypeScript.
#
# The front-end code is written in JavaScript using the React framework.
#
# WHAT WE'RE LOOKING FOR
#
# A solid grasp of general programming principles and backend infrastructure
# Excellent programming skills in JavaScript, Node.js and working knowledge of Typescript
# Experience with Amazon Web Services such as: Lambda, API Gateway, EC2, RDS/ Aurora, S3, IAM, Route 53, Cloudfront, Elasticache/ Redis
# Ability to work both independently and with a wide variety of teams
# Knowledge of GraphQL APIs, serverless applications and Jest unit testing are a plus
# Passion for improving education through technology and games
#
# ABOUT IXL
#
# IXL Learning is a leading educational technology company on a big mission: creating innovative learning experiences that help all learners reach their full potential. IXL's comprehensive curriculum and insightful analytics help more than 500,000 teachers deliver personalized instruction and empower over 10 million students to achieve new learning milestones every day.
#
# At IXL, we’re passionate about our mission of creating the best educational technology that improves learning for all students. We bring that same passion to creating a workplace that values diversity on the basis that all of us bring a unique perspective and experience that advances IXL’s mission.
#
# We strive to increase diversity in race, ethnicity, gender, age, sexual orientation, and physical or mental ability and to continually promote a work environment where everyone, from any background, can do their best work.
# Click here to apply
# job Title: Software Developer Programmer
# Location: N/A
# Date:  Sep 21
# Link:  https://providence.craigslist.org/sof/d/cranston-software-developer-programmer/7200368391.html /n
# compensation: We offer a competitive compensation and benefits package
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Job Description
# SR2Software is seeking individuals with expertise in one or more of the following languages and/or technologies: Visual Basic, VB Script, ProvideX (PXPlus), Progress 4GL, .Net, HTML, PHP, ODBC, MySQL, XML, Microsoft SharePoint.
# Role & Responsibilities
# •	Contribute to software development lifecycle activities, including estimating, architecture, design, development, database programming, integration, testing, deployment, maintenance and support
# •	Collaborate with team on system architecture decisions
# •	Consult with clients and technical personnel to clarify program’s intent, identify problems, and suggest changes
# •	Write technical documentation
# •	Assist with testing recommendations
# •	Provide status reports to management
# •	Collaboratively work with project team to deliver effective system solutions
# •	Develop mutually productive relationships in the workplace and contribute to the team
# Skills
# •	Experience with multi-tiered application architecture
# •	Skilled in software development using Visual Basic, ProvideX, Progress other programming languages
# •	Database design and data management
# •	Ability to estimate work and meet deadlines
# •	Strong written and oral communications skills
# •	Self-starter and able to work as part of small team or independently with minimum supervision
# •	Ability to think creatively and desire to keep current with new technologies
#
# Qualifications & Experience
# •	Software Applications Development experience required
# •	Experience using Windows and the web as the user interface
# •	Must be knowledgeable with all aspects of SDLC (Systems Development Life Cycle)
# •	College degree or related field with minimum 2 years application development experience
# •	Demonstrated knowledge of the following technologies:
# o	Operating Environments: Windows and Windows Server environments
# o	Languages: Visual Basic, ProvideX (PxPlus), Progress 4GL, HTML, PHP Scripting, VBScript, MySQL, XML
# o	Databases: MySQL Server, PVX Technologies, Progress RDBMS
# o	Special OS Technologies: Terminal Services, Internet Information Server (IIS), ODBC
# o	Development Tools and Applications: Visual Studio, PXPlus Nomads, Progress OpenEdge, .Net, Microsoft SharePoint Designer
#
# job Title: PHP XML Web Developer Work
# Location: N/A
# Date:  Sep 17
# Link:  https://providence.craigslist.org/sof/d/php-xml-web-developer-work/7197965448.html /n
# compensation: negotiable
#
# employment type: part-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# RI Web based marketing company established in 2000, is seeking a local applicant to work part time on our platform focusing on PHP and XML integrations.
#
# This would be off site, part time, but a commitment is needed - anticipation would be 5 to 10 hours/week.
#
# Description;
#
# Environment is web based,  PHP/MySQL as well as utilizing XML integration.
#
# We need to upgrade the PHP version our platform is currently using.
#
# This work would focus on developing, enhancing and maintaining our web based information system.
#
# You must be able to decipher, work with and improve older code our platform is built on, including an upgrade in the current PHP version which will entail chasing down errors.
#
# An essential part of the job is matching up data fields that clients ping us with to the data fields our customers require in order to post to them. Working with our systems and our partners APIs to send and receive data via XML and GET posting.
#
# And maintaining our customer and product data bases.
#
# Requirements/Skills
#
# MUST have;
# PHP and MySQL experience in a LAMP environment.
# Ping / post experience.
# Plesk server environment.
# XML experience.
# Must have the ability to work with existing, older code and frameworks.
# Knowledge with Web Standards and modern HTML/CSS markup.
# Javascript/jQuery experience.
#
# Personality Type
#
# Able to work independently to complete work.
# Ability to work with existing system and code.
#
# Location
#
# East Greenwich, RI - we are looking for a local person, but work is done from home.
#
# Compensation commensurate with experience and skill level.
#
# TO APPLY
#
# - If you have an interest in the position please respond via this ad and list qualifications.
#
#
#
# job Title: Database Specialist
# Location: N/A
# Date:  Sep 23
# Link:  https://capecod.craigslist.org/sof/d/woods-hole-database-specialist/7201466507.html /n
# compensation: DOE
#
# employment type: full-time
#
# telecommuting ok
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Background
# The Northeast Fisheries Science Center (NEFSC) Data Management Systems Program (DMS) supports Information Technology (IT) services for various laboratories and field stations from Maine to New Jersey. NEFSC programs and remote offices have applications and systems that rely on DMS provided infrastructure and operational capability to execute their mission. These mission requirements are derived from the Magnuson-Stevens Fishery Conservation and Management Act and can vary based on many factors including legislative changes, NMFS/NOAA/Department of Commerce/Office of Management of Budget requirements and legal guidance.
#
# Position Description
# Will be responsible for ensuring the efficient and effective operation and usage of data and the integration of the NEFSC data management process in order to meet service level requirements. Will be responsible for accumulating, cataloging, and documenting the workflow of NEFSC data. Oversees the development and use of data systems and discovers efficient ways to organize, store and analyze data with attention to security and confidentiality. These tasks are illustrative only and may include other related duties. These tasks will be performed in support of and in close coordination with other contracting resources and government employees. Specific duties include:
#
# - Maintains databases and conducts routine maintenance as needed to ensure data integrity.
# Streamlines data collection and analysis procedures.
# - Works with Database Administrators to generate and review documentation for all database changes or refinements.
# - Provides data management support to users.
# - Makes recommendations for software, hardware, and data storage upgrades
# - Modifies databases according to requests and performs tests to solve database usage issues and malfunctions.
# - Gathers user requirements, identifies new features, and liaisons with application developers to improve applications and establish best practices.
# - Ensures all database programs meet organizational and performance requirements.
# - Develops technical and training manuals.
# - Coordinates with all Federal and contract employees where necessary to communicate database management impacts on baseline infrastructure systems governed by the CCB, and other entities that manage changes to the overall NEFSC IT infrastructure.
# - Work in concurrence with IT Security Officer (ITSO) to maintain and implement Operating and Database Application Systems Support Services security.
# - Produce documented requirements and project plans in consultation with Project Managers as required to execute project-based database management and development tasks.
# - Deliver and maintain Standard Operating Procedures (SOP) library in the areas of database management and development.
#
# Required Skills
# 2+ years of experience with database management and development. Experience developing secure web-based applications using Oracle APEX.
#
# - Experience establishing, organizing, and implementing data management policies, principles, best practices, standards, and organization of data including secure access.
# - Experience with data governance which includes maintaining data integrity, improving efficiency, and ensuring availability of data.
# - Detail oriented and organized with strong analytical skills.
# - Demonstrated success working in a team environment that includes flexibility working with a team in an organization that is dispersed; coordinating with the work of others; facilitating interactions among team members with diverse skill sets.
# - Demonstrated experience supporting program development through integrated project work group meetings and system reviews for quality and performance.
# - Possess excellent written and verbal communication skills.
#
# Desired
#
# -Knowledge and extensive experience with the Oracle DBMS including design, development (PL/SQL), testing, optimization, and implementation of Oracle architecture-based solutions.
# -Agile Development experience or similar methodology, desired.
#
# Must be a US Citizen or Permanent Resident and be able to pass a background investigation to obtain a security badge to enter the applicable government facility.
#
# Education
# BS in Computer Science, related degree, or equivalent.
#
# Submit resume to ERT's Career Opportunities Web Page at: https://chu.tbe.taleo.net/chu04/ats/careers/searchResults.jsp?org=ERT&cws=1
#
# Earth Resources Technology, Inc. (ERT)
# ERT is a VEVRAA Federal Contractor and Equal Opportunity/Affirmative Action employer - All qualified applicants will be considered for employment without regard to race, color, religion, sex, national origin, disability, or protected Veteran status.
# job Title: Need help working with “Shopify” software
# Location: N/A
# Date:  Sep 10
# Link:  https://hartford.craigslist.org/sof/d/bloomfield-need-help-working-with/7193804118.html /n
# compensation: $50 per hours
#
# employment type: contract
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# I need some help working with a Shopify website.  Looking for one or two hours of professional consulting to help understand some of the functions of the web site.  I already know most of the operations like posting, shipping, customer operations, etc. but need to understand more about linking products and filing shipping claims.  I am looking for someone highly qualified.  Will pay $50 per hour cash thinking that I need about two hours spaced out about a week or two a part.  If you have the skills for this and want the work please respond by text. 860-970-8980 or email.
